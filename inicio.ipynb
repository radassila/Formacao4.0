# %% [markdown]
# # Conhecendo o Python
#
# Bem-vinda ao estudo da linguagem python

# %%
x = 1
y = 0.1324

print('x vale',x)
print('y vale',y)
# Out:
# x vale 1
# y vale 0.1324

# %% [markdown]
# ## TRABALHANDO COM PANDAS

# %%
import pandas as pd
import numpy as np
serie = pd.Series([3,7,6,5,4,'teste',8,np.nan])
print(serie)

# %%
df = pd.DataFrame(np.random.randint(1,5,size=(6,4)),
                  columns=['A','B','C','D'],
                  )
